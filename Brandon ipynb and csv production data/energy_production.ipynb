# %%
#Dependencies
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
import csv

# %%
file_RE = "Resources/generation_annual_RE.csv"

# %%
renewable_df = pd.read_csv(file_RE)

# %%
renewable_df[]
# Out:
#     YEAR STATE_CODE                                       SECTOR_NAME  \
# 0   1990         AK                     Total Electric Power Industry
# 1   1990         AK                     Total Electric Power Industry
# 2   1990         AK                     Total Electric Power Industry
# 3   1990         AK                     Total Electric Power Industry
# 4   1990         AK                     Total Electric Power Industry
# 5   1990         AK                     Total Electric Power Industry
# 6   1990         AK                     Total Electric Power Industry
# 7   1990         AK           Electric Generators, Electric Utilities
# 8   1990         AK           Electric Generators, Electric Utilities
# 9   1990         AK           Electric Generators, Electric Utilities
# 10  1990         AK           Electric Generators, Electric Utilities
# 11  1990         AK           Electric Generators, Electric Utilities
# ...

# %%
indexNames = renewable_df[ (renewable_df['ENERGY_SOURCE'] != "Hydroelectric Conventional") & (renewable_df['ENERGY_SOURCE'] != "Wind") ].index
renewable_df.drop(indexNames , inplace=True)

# %%
RE_prod_df = pd.read_csv(file_one)

# %%
RE_prod_df
# Out:
#        Year State Code                              Producer Type  \
# 0      1990         AK  Combined Heat and Power, Commercial Power
# 1      1990         AK  Combined Heat and Power, Commercial Power
# 2      1990         AK  Combined Heat and Power, Commercial Power
# 3      1990         AK  Combined Heat and Power, Industrial Power
# 4      1990         AK  Combined Heat and Power, Industrial Power
# ...     ...        ...                                        ...
# 40894  2016         WY              Total Electric Power Industry
# 40895  2016         WY              Total Electric Power Industry
# 40896  2016         WY              Total Electric Power Industry
# 40897  2016         WY              Total Electric Power Industry
# 40898  2016         WY              Total Electric Power Industry
#
#        Fuel Source Generators Facilities Nameplate Capacity (Megawatts)  \
# 0      All Sources        NaN          4                           85.9
# ...

# %%
RE_prod_df[RE_prod_df["Year"]> 2000]
# Out:
#        Year State Code                              Producer Type  \
# 15039  2001         AK  Combined Heat and Power, Commercial Power
# 15040  2001         AK  Combined Heat and Power, Commercial Power
# 15041  2001         AK  Combined Heat and Power, Commercial Power
# 15042  2001         AK    Combined Heat and Power, Electric Power
# 15043  2001         AK    Combined Heat and Power, Electric Power
# ...     ...        ...                                        ...
# 40894  2016         WY              Total Electric Power Industry
# 40895  2016         WY              Total Electric Power Industry
# 40896  2016         WY              Total Electric Power Industry
# 40897  2016         WY              Total Electric Power Industry
# 40898  2016         WY              Total Electric Power Industry
#
#        Fuel Source Generators Facilities Nameplate Capacity (Megawatts)  \
# 15039  All Sources        NaN          6                           53.0
# ...

# %%
RE_prod_df.tail(30)
# Out:
#        Year State Code                                     Producer Type  \
# 40869  2016         WV                     Total Electric Power Industry
# 40870  2016         WV                     Total Electric Power Industry
# 40871  2016         WV                     Total Electric Power Industry
# 40872  2016         WV                     Total Electric Power Industry
# 40873  2016         WV                     Total Electric Power Industry
# 40874  2016         WV                     Total Electric Power Industry
# 40875  2016         WY           Electric Generators, Electric Utilities
# 40876  2016         WY           Electric Generators, Electric Utilities
# 40877  2016         WY           Electric Generators, Electric Utilities
# 40878  2016         WY           Electric Generators, Electric Utilities
# 40879  2016         WY           Electric Generators, Electric Utilities
# 40880  2016         WY           Electric Generators, Electric Utilities
# ...

# %%
print(RE_prod_df.loc[RE_prod_df['Fuel Source'].isin(['Wind','Hydroelectric', 'All Sources'])])
# Out:
#        Year State Code                                     Producer Type  \
# 0      1990         AK         Combined Heat and Power, Commercial Power
# 3      1990         AK         Combined Heat and Power, Industrial Power
# 7      1990         AK           Electric Generators, Electric Utilities
# 9      1990         AK           Electric Generators, Electric Utilities
# 12     1990         AK           Electric Generators, Electric Utilities
# ...     ...        ...                                               ...
# 40884  2016         WY  Electric Generators, Independent Power Producers
# 40885  2016         WY                                  Industrial Power
# 40891  2016         WY                     Total Electric Power Industry
# 40893  2016         WY                     Total Electric Power Industry
# 40898  2016         WY                     Total Electric Power Industry
#
#          Fuel Source Generators Facilities Nameplate Capacity (Megawatts)  \
# ...

# %%
RE_prod_df.drop(['Producer Type'], axis=1)
# Out:
#        Year State Code  Fuel Source Generators Facilities  \
# 0      1990         AK  All Sources        NaN          4
# 1      1990         AK         Coal        NaN          3
# 2      1990         AK    Petroleum        NaN          1
# 3      1990         AK  All Sources        NaN         23
# 4      1990         AK  Natural Gas        NaN         28
# ...     ...        ...          ...        ...        ...
# 40894  2016         WY  Natural Gas         26         10
# 40895  2016         WY        Other          1          1
# 40896  2016         WY  Other Gases          7          3
# 40897  2016         WY    Petroleum          4          3
# 40898  2016         WY         Wind         31         21
#
#       Nameplate Capacity (Megawatts) Summer Capacity (Megawatts)
# 0                               85.9                        80.1
# 1                               65.5                        61.1
# 2                               20.4                        19.0
# ...

# %%
RE_prod_df.head(100)
# Out:
#     Year State Code                              Producer Type  \
# 0   1990         AK  Combined Heat and Power, Commercial Power
# 1   1990         AK  Combined Heat and Power, Commercial Power
# 2   1990         AK  Combined Heat and Power, Commercial Power
# 3   1990         AK  Combined Heat and Power, Industrial Power
# 4   1990         AK  Combined Heat and Power, Industrial Power
# ..   ...        ...                                        ...
# 95  1990         CA    Combined Heat and Power, Electric Power
# 96  1990         CA    Combined Heat and Power, Electric Power
# 97  1990         CA    Combined Heat and Power, Electric Power
# 98  1990         CA    Combined Heat and Power, Electric Power
# 99  1990         CA  Combined Heat and Power, Industrial Power
#
#                     Fuel Source Generators Facilities  \
# 0                   All Sources        NaN          4
# 1                          Coal        NaN          3
# ...

# %%
RE_prod_df.tail(77
               )
# Out:
#        Year State Code                                     Producer Type  \
# 40822  2016         WI           Electric Generators, Electric Utilities
# 40823  2016         WI  Electric Generators, Independent Power Producers
# 40824  2016         WI  Electric Generators, Independent Power Producers
# 40825  2016         WI  Electric Generators, Independent Power Producers
# 40826  2016         WI  Electric Generators, Independent Power Producers
# ...     ...        ...                                               ...
# 40894  2016         WY                     Total Electric Power Industry
# 40895  2016         WY                     Total Electric Power Industry
# 40896  2016         WY                     Total Electric Power Industry
# 40897  2016         WY                     Total Electric Power Industry
# 40898  2016         WY                     Total Electric Power Industry
#
#                        Fuel Source Generators Facilities  \
# ...

# %%
indexNames = RE_prod_df[ (RE_prod_df['Fuel Source'] == Petroleum) & (RE_prod_df['Fuel Source'] == Other Gases) & (RE_prod_df['Fuel Source'] == Other) & (RE_prod_df['Fuel Source'] == Natural Gas) & (RE_prod_df['Fuel Source'] == Coal)
& (RE_prod_df['Fuel Source'] == Wood and Wood Derived Fuels) & (RE_prod_df['Fuel Source'] == Other Biomass) & (RE_prod_df['Fuel Source'] == Nuclear)].index
    
RE_prod_df.drop(indexNames , inplace=True)
# Out:
#   File "<ipython-input-11-4977e2cefac7>", line 1
#     indexNames = RE_prod_df[ (RE_prod_df['Fuel Source'] == Petroleum) & (RE_prod_df['Fuel Source'] == Other Gases) & (RE_prod_df['Fuel Source'] == Other) & (RE_prod_df['Fuel Source'] == Natural Gas) & (RE_prod_df['Fuel Source'] == Coal)
#                                                                                                                 ^
# SyntaxError: invalid syntax
